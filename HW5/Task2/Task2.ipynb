# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.abs((x + 4) * (x + 3) * (x + 2) * (x + 1))

a = -4
b = -1
xs = np.linspace(a, b, 10000)
ys = f(xs)

plt.figure(figsize=(8,5))
plt.plot(xs, ys)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
